# %% [markdown]
# # Good Deal / Bad Deal Indicator

# %% [markdown]
# **In This Notebook**: Create a simple price estimate using Linear Regression.
#
# **In Tableau**: Visualize price estimates vs actual prices to determine what is a good deal vs bad deal.

# %% [markdown]
# ## 1. Read in Chicago Listings

# %%
# import libraries
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %%
# read in Chicago listings
data_chicago = pd.read_csv('../Exercises/redfin_listings_chicago.csv')
data_chicago.head()
# Out:
#      SALE TYPE  SOLD DATE              PROPERTY TYPE  \
# 0  MLS Listing        NaN                Condo/Co-op
# 1  MLS Listing        NaN  Single Family Residential
# 2  MLS Listing        NaN  Single Family Residential
# 3  MLS Listing        NaN                Condo/Co-op
# 4  MLS Listing        NaN  Single Family Residential
#
#                     ADDRESS     CITY STATE OR PROVINCE  ZIP OR POSTAL CODE  \
# 0  1335 S Prairie Ave #1105  Chicago                IL               60605
# 1          4944 W Roscoe St  Chicago                IL               60641
# 2     8111 S Scottsdale Ave  Chicago                IL               60652
# 3       4335 N Mozart St #1  Chicago                IL               60618
# 4        5736 S Loomis Blvd  Chicago                IL               60636
#
#     PRICE  BEDS  BATHS  ...  STATUS  NEXT OPEN HOUSE START TIME  \
# 0  799000   3.0    2.5  ...  Active                         NaN
# 1  424900   4.0    3.5  ...  Active                         NaN
# 2  265000   3.0    1.0  ...  Active                         NaN
# 3  325000   3.0    2.0  ...  Active   November-14-2021 11:00 AM
# 4  159900   5.0    2.0  ...  Active                         NaN
#
#     NEXT OPEN HOUSE END TIME  \
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3  November-14-2021 12:30 PM
# 4                        NaN
#
#    URL (SEE http://www.redfin.com/buy-a-home/comparative-market-analysis FOR INFO ON PRICING)  \
# 0  http://www.redfin.com/IL/Chicago/1335-S-Prairi...
# 1  http://www.redfin.com/IL/Chicago/4944-W-Roscoe...
# 2  http://www.redfin.com/IL/Chicago/8111-S-Scotts...
# 3  http://www.redfin.com/IL/Chicago/4335-N-Mozart...
# 4  http://www.redfin.com/IL/Chicago/5736-S-Loomis...
#
#    SOURCE      MLS#  FAVORITE INTERESTED   LATITUDE  LONGITUDE
# 0    MRED  11268174         N          Y  41.864674 -87.620765
# 1    MRED  11268165         N          Y  41.942626 -87.751249
# 2    MRED  11268170         N          Y  41.745964 -87.737172
# 3    MRED  11266874         N          Y  41.960457 -87.699344
# 4    MRED  11268151         N          Y  41.789370 -87.659866
#
# [5 rows x 27 columns]

# %%
# only look at numeric values to create a simple model
data_subset = data_chicago[["PRICE", "BEDS", "BATHS", "SQUARE FEET", "YEAR BUILT"]]
data_subset = data_subset.dropna()
data_subset
# Out:
#       PRICE  BEDS  BATHS  SQUARE FEET  YEAR BUILT
# 0    799000   3.0    2.5       2076.0      2003.0
# 1    424900   4.0    3.5       2921.0      1924.0
# 2    265000   3.0    1.0        998.0      1956.0
# 3    325000   3.0    2.0       1875.0      2002.0
# 4    159900   5.0    2.0       1953.0      1906.0
# ..      ...   ...    ...          ...         ...
# 337  239000   2.0    2.0       1100.0      1969.0
# 338  649000   3.0    2.0       1700.0      2004.0
# 339  265000   1.0    1.0        770.0      1924.0
# 341  245000   3.0    2.0       1200.0      1926.0
# 342  190000   3.0    2.0       1500.0      2006.0
#
# [199 rows x 5 columns]

# %% [markdown]
# ## 2. Fit a Model to Predict Home Price

# %%
# set the dependent variable / output as price
y = data_subset.PRICE
y
# Out:
# 0      799000
# 1      424900
# 2      265000
# 3      325000
# 4      159900
#         ...
# 337    239000
# 338    649000
# 339    265000
# 341    245000
# 342    190000
# Name: PRICE, Length: 199, dtype: int64

# %%
# set the independent variables / inputs as the numeric fields
X = data_subset[["BEDS", "BATHS", "SQUARE FEET", "YEAR BUILT"]]
X
# Out:
#      BEDS  BATHS  SQUARE FEET  YEAR BUILT
# 0     3.0    2.5       2076.0      2003.0
# 1     4.0    3.5       2921.0      1924.0
# 2     3.0    1.0        998.0      1956.0
# 3     3.0    2.0       1875.0      2002.0
# 4     5.0    2.0       1953.0      1906.0
# ..    ...    ...          ...         ...
# 337   2.0    2.0       1100.0      1969.0
# 338   3.0    2.0       1700.0      2004.0
# 339   1.0    1.0        770.0      1924.0
# 341   3.0    2.0       1200.0      1926.0
# 342   3.0    2.0       1500.0      2006.0
#
# [199 rows x 4 columns]

# %%
# train/test split before fitting model
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=1118)

# %%
# fit a linear regression model
lr = LinearRegression()
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ## 3. Look at the Metrics

# %%
# view R-squared
lr.score(X_test, y_test)
# Out:
# 0.6502841724507231

# %%
# view RMSE (root mean squared error)
actual = y_test
predicted = lr.predict(X_test)
mean_squared_error(actual, predicted)**.5
# Out:
# 205458.48700571858

# %% [markdown]
# ## 4. View Price Estimates

# %%
# price estimates for each home based on model
price_estimates = lr.predict(X)
data_subset["PRICE_ESTIMATE"] = price_estimates.tolist()
data_subset
# Out:
#       PRICE  BEDS  BATHS  SQUARE FEET  YEAR BUILT  PRICE_ESTIMATE
# 0    799000   3.0    2.5       2076.0      2003.0    7.262737e+05
# 1    424900   4.0    3.5       2921.0      1924.0    1.007532e+06
# 2    265000   3.0    1.0        998.0      1956.0    1.394202e+04
# 3    325000   3.0    2.0       1875.0      2002.0    5.557068e+05
# 4    159900   5.0    2.0       1953.0      1906.0    2.537927e+05
# ..      ...   ...    ...          ...         ...             ...
# 337  239000   2.0    2.0       1100.0      1969.0    3.813045e+05
# 338  649000   3.0    2.0       1700.0      2004.0    5.023633e+05
# 339  265000   1.0    1.0        770.0      1924.0    1.235892e+05
# 341  245000   3.0    2.0       1200.0      1926.0    2.553778e+05
# 342  190000   3.0    2.0       1500.0      2006.0    4.410766e+05
#
# [199 rows x 6 columns]

# %%
## merge back with original data set
price_estimates = pd.merge(data_chicago, data_subset, left_index=True, right_index=True, suffixes=(None, '_Duplicate'))
price_estimates
# Out:
#        SALE TYPE  SOLD DATE              PROPERTY TYPE  \
# 0    MLS Listing        NaN                Condo/Co-op
# 1    MLS Listing        NaN  Single Family Residential
# 2    MLS Listing        NaN  Single Family Residential
# 3    MLS Listing        NaN                Condo/Co-op
# 4    MLS Listing        NaN  Single Family Residential
# ..           ...        ...                        ...
# 337  MLS Listing        NaN                Condo/Co-op
# 338  MLS Listing        NaN                Condo/Co-op
# 339  MLS Listing        NaN                Condo/Co-op
# 341  MLS Listing        NaN  Single Family Residential
# 342  MLS Listing        NaN                Condo/Co-op
#
#                          ADDRESS     CITY STATE OR PROVINCE  \
# 0       1335 S Prairie Ave #1105  Chicago                IL
# 1               4944 W Roscoe St  Chicago                IL
# 2          8111 S Scottsdale Ave  Chicago                IL
# 3            4335 N Mozart St #1  Chicago                IL
# 4             5736 S Loomis Blvd  Chicago                IL
# ..                           ...      ...               ...
# 337  3930 N Pine Grove Ave #1515  Chicago                IL
# 338          1359 N Mohawk St #3  Chicago                IL
# 339      310 S Michigan Ave #910  Chicago                IL
# 341                70 E 101st St  Chicago                IL
# 342       5420 S Michigan Ave #4  Chicago                IL
#
#      ZIP OR POSTAL CODE   PRICE  BEDS  BATHS  ... FAVORITE  INTERESTED  \
# 0                 60605  799000   3.0    2.5  ...        N           Y
# 1                 60641  424900   4.0    3.5  ...        N           Y
# 2                 60652  265000   3.0    1.0  ...        N           Y
# 3                 60618  325000   3.0    2.0  ...        N           Y
# 4                 60636  159900   5.0    2.0  ...        N           Y
# ..                  ...     ...   ...    ...  ...      ...         ...
# 337               60613  239000   2.0    2.0  ...        N           Y
# 338               60610  649000   3.0    2.0  ...        N           Y
# 339               60604  265000   1.0    1.0  ...        N           Y
# 341               60628  245000   3.0    2.0  ...        N           Y
# 342               60615  190000   3.0    2.0  ...        N           Y
#
#       LATITUDE  LONGITUDE  PRICE_Duplicate  BEDS_Duplicate  BATHS_Duplicate  \
# 0    41.864674 -87.620765           799000             3.0              2.5
# 1    41.942626 -87.751249           424900             4.0              3.5
# 2    41.745964 -87.737172           265000             3.0              1.0
# 3    41.960457 -87.699344           325000             3.0              2.0
# 4    41.789370 -87.659866           159900             5.0              2.0
# ..         ...        ...              ...             ...              ...
# 337  41.954237 -87.648457           239000             2.0              2.0
# 338  41.907243 -87.641827           649000             3.0              2.0
# 339  41.877825 -87.624602           265000             1.0              1.0
# 341  41.711045 -87.620971           245000             3.0              2.0
# 342  41.795913 -87.622861           190000             3.0              2.0
#
#     SQUARE FEET_Duplicate YEAR BUILT_Duplicate PRICE_ESTIMATE
# 0                  2076.0               2003.0   7.262737e+05
# 1                  2921.0               1924.0   1.007532e+06
# 2                   998.0               1956.0   1.394202e+04
# 3                  1875.0               2002.0   5.557068e+05
# 4                  1953.0               1906.0   2.537927e+05
# ..                    ...                  ...            ...
# 337                1100.0               1969.0   3.813045e+05
# 338                1700.0               2004.0   5.023633e+05
# 339                 770.0               1924.0   1.235892e+05
# 341                1200.0               1926.0   2.553778e+05
# 342                1500.0               2006.0   4.410766e+05
#
# [199 rows x 33 columns]

# %% [markdown]
# ## 5. Export Price Estimates

# %%
# export data to read into Tableau
price_estimates.to_csv('chicago_price_estimates.csv')
